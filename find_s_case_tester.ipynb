# %% [markdown]
# # Program1 : Implement and demonstrate the FIND-S algorithm for finding the most specific hypothesis based on a given set of training data samples. Read the training data from a .CSV file.

# %%
import random
import csv
from pprint import pprint


attributes = [['Sunny','Rainy'],
              ['Warm','Cold'],
              ['Normal','High'],
              ['Strong','Weak'],
              ['Warm','Cool'],
              ['Same','Change']]


num_attributes = len(attributes)


print("The most general hypothesis : ['?','?','?','?','?','?']")
print(" The most specific hypothesis : ['0','0','0','0','0','0']")

a = []


with open('ws.csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        a.append(row)
        #print(row)
# Out:
# The most general hypothesis : ['?','?','?','?','?','?']
#  The most specific hypothesis : ['0','0','0','0','0','0']

# %%
print(" The initial value of hypothesis: ")
print()

hypothesis = ['0'] * num_attributes
print(hypothesis)

for j in range(0,num_attributes):
        hypothesis[j] = a[0][j];

print(hypothesis)
print()

for i in range(0,len(a)):
    if a[i][num_attributes]=='Yes':
            for j in range(0,num_attributes):
                if a[i][j]!=hypothesis[j]:
                    hypothesis[j]='?'
                else :
                    hypothesis[j]= a[i][j]
# Out:
#  The initial value of hypothesis:
#
# ['0', '0', '0', '0', '0', '0']
# ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same']

# %%
#find S algorithms
print(hypothesis)
#test_case = list(map(str, input("Enter a test case with elements comma seperated ").split(',')))
# Out:
# ['Sunny', 'Warm', '?', 'Strong', '?', '?']

# %%
def is_case_valid(attributes, case):
    
        attribs = [   [i.lower() for i in l] for l in attributes]
        case = [ i.lower() for i in case]
        if len(case) != len(attribs):
            return False
        
        for j,i in enumerate(case):
            if  i not in attribs[j]:
               
                return False 
        return True

# %%
def outcome_finder(hypothesis, case):
    not_question_mark_indices = [ j  for j,i in enumerate(hypothesis) if i != '?' ]
    for i in not_question_mark_indices :
        if case[i] != hypothesis[i]:
            return "No"
    return 'Yes'

# %%
import random, pandas 

records= []


for _ in range(100):
    case = [ random.choice(i) for i in attributes]
    if is_case_valid(attributes, case):
       records.append(    [  ','.join(case), outcome_finder(hypothesis,case)]      )
    

data_frame = pandas.DataFrame(records)
data_frame
# Out:
#                                        0    1
# 0     Rainy,Cold,Normal,Weak,Cool,Change   No
# 1       Rainy,Cold,High,Strong,Cool,Same   No
# 2       Sunny,Cold,High,Weak,Warm,Change   No
# 3     Rainy,Warm,High,Strong,Warm,Change   No
# 4   Rainy,Cold,Normal,Strong,Warm,Change   No
# 5       Sunny,Warm,High,Strong,Warm,Same  Yes
# 6     Sunny,Warm,Normal,Weak,Cool,Change   No
# 7     Rainy,Warm,Normal,Strong,Cool,Same   No
# 8       Sunny,Warm,Normal,Weak,Warm,Same   No
# 9         Rainy,Warm,High,Weak,Cool,Same   No
# 10  Sunny,Warm,Normal,Strong,Warm,Change  Yes
# 11      Rainy,Warm,Normal,Weak,Warm,Same   No
# 12    Sunny,Cold,Normal,Strong,Warm,Same   No
# 13      Sunny,Warm,High,Weak,Cool,Change   No
# 14  Rainy,Cold,Normal,Strong,Warm,Change   No
# 15        Rainy,Warm,High,Weak,Warm,Same   No
# 16  Rainy,Cold,Normal,Strong,Cool,Change   No
# 17      Sunny,Cold,High,Strong,Warm,Same   No
# 18      Sunny,Warm,Normal,Weak,Cool,Same   No
# 19  Rainy,Warm,Normal,Strong,Cool,Change   No
# 20    Sunny,Warm,Normal,Strong,Cool,Same  Yes
# 21    Rainy,Warm,High,Strong,Warm,Change   No
# 22      Rainy,Cold,High,Strong,Warm,Same   No
# 23    Sunny,Cold,Normal,Strong,Cool,Same   No
# 24    Sunny,Cold,Normal,Weak,Warm,Change   No
# 25      Rainy,Warm,High,Strong,Cool,Same   No
# 26    Rainy,Warm,Normal,Weak,Warm,Change   No
# 27    Rainy,Warm,Normal,Strong,Warm,Same   No
# 28      Rainy,Cold,Normal,Weak,Cool,Same   No
# 29      Rainy,Warm,Normal,Weak,Cool,Same   No
# ..                                   ...  ...
# 70    Sunny,Cold,High,Strong,Cool,Change   No
# 71  Sunny,Warm,Normal,Strong,Warm,Change  Yes
# 72    Sunny,Cold,High,Strong,Cool,Change   No
# 73    Sunny,Warm,High,Strong,Warm,Change  Yes
# 74    Sunny,Warm,Normal,Weak,Cool,Change   No
# 75    Sunny,Warm,Normal,Strong,Cool,Same  Yes
# 76      Rainy,Cold,High,Strong,Warm,Same   No
# 77      Rainy,Warm,High,Strong,Cool,Same   No
# 78      Sunny,Cold,High,Strong,Cool,Same   No
# 79      Sunny,Warm,Normal,Weak,Cool,Same   No
# 80    Sunny,Warm,High,Strong,Cool,Change  Yes
# 81    Sunny,Warm,Normal,Weak,Warm,Change   No
# 82    Sunny,Warm,High,Strong,Cool,Change  Yes
# 83      Rainy,Warm,High,Strong,Cool,Same   No
# 84    Rainy,Warm,High,Strong,Warm,Change   No
# 85      Rainy,Cold,High,Strong,Cool,Same   No
# 86      Rainy,Warm,High,Weak,Warm,Change   No
# 87    Rainy,Cold,High,Strong,Warm,Change   No
# 88      Sunny,Warm,High,Strong,Cool,Same  Yes
# 89    Rainy,Cold,Normal,Weak,Warm,Change   No
# 90  Sunny,Cold,Normal,Strong,Warm,Change   No
# 91    Rainy,Warm,High,Strong,Cool,Change   No
# 92      Rainy,Warm,High,Strong,Warm,Same   No
# 93    Sunny,Warm,Normal,Strong,Warm,Same  Yes
# 94    Sunny,Warm,Normal,Weak,Cool,Change   No
# 95    Sunny,Warm,High,Strong,Cool,Change  Yes
# 96    Sunny,Warm,Normal,Strong,Warm,Same  Yes
# 97  Rainy,Warm,Normal,Strong,Warm,Change   No
# 98      Sunny,Warm,Normal,Weak,Cool,Same   No
# 99    Rainy,Cold,Normal,Weak,Warm,Change   No
#
# [100 rows x 2 columns]

# %%
is_case_valid(attributes, ['Sunny', 'Warm', 'Normal', 'Strong', 'Warm', 'Same'])
# Out:
# True
